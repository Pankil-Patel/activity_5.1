# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner
# 1           Coffee House         2h  Female  21  Unmarried partner
# 2  Carry out & Take away         2h  Female  21  Unmarried partner
# 3           Coffee House         2h  Female  21  Unmarried partner
# 4           Coffee House         1d  Female  21  Unmarried partner
#
#    has_children                 education  occupation           income  car  \
# 0             1  Some college - no degree  Unemployed  $37500 - $49999  NaN
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
# To investigate the data, the first step is to understand the different column object types using )
# data.info(). It also shows the columns where the data is NaN or is Null
data.info()

# Before cleaning up the data, we first want to understand the type of data each of the column contains
# It helps with three things 
#   a. Understand the different values each of the column contains
#   b. Understand the data and what filter criteria we can use to analyze the data
#   c. Understand data which looks incorrect and whether to clean it up or remove those records
# Below is the print out of different columns with unique values it contains.
# value_counts() doesn't show the counts of nulls in a column
dataInfoColumns = data.columns.tolist()
data1 = pd.DataFrame(data["destination"].value_counts())
data2 = pd.DataFrame(data["passanger"].value_counts())
data3 = pd.DataFrame(data["weather"].value_counts())
data4 = pd.DataFrame(data["temperature"].value_counts())
data5 = pd.DataFrame(data["time"].value_counts())
data6 = pd.DataFrame(data["coupon"].value_counts())
data7 = pd.DataFrame(data["expiration"].value_counts())
data8 = pd.DataFrame(data["gender"].value_counts())
data9 = pd.DataFrame(data["age"].value_counts())
data10 = pd.DataFrame(data["maritalStatus"].value_counts())
data11 = pd.DataFrame(data["has_children"].value_counts())
data12 = pd.DataFrame(data["education"].value_counts())
data13 = pd.DataFrame(data["occupation"].value_counts())
data14 = pd.DataFrame(data["income"].value_counts())
data15 = pd.DataFrame(data["car"].value_counts())
data16 = pd.DataFrame(data["Bar"].value_counts())
data17 = pd.DataFrame(data["CoffeeHouse"].value_counts())
data18 = pd.DataFrame(data["CarryAway"].value_counts())
data19 = pd.DataFrame(data["RestaurantLessThan20"].value_counts())
data20 = pd.DataFrame(data["Restaurant20To50"].value_counts())
data21 = pd.DataFrame(data["toCoupon_GEQ5min"].value_counts())
data22 = pd.DataFrame(data["toCoupon_GEQ15min"].value_counts())
data23 = pd.DataFrame(data["toCoupon_GEQ25min"].value_counts())
data24 = pd.DataFrame(data["direction_same"].value_counts())
data25 = pd.DataFrame(data["direction_opp"].value_counts())
data26 = pd.DataFrame(data["Y"].value_counts())

# Printing all the column values to review it later
#print(data1)
#print(data2)
#print(data3)
#print(data4)
#print(data5)
#print(data6)
#print(data7)
#print(data8)
#print(data9)
#print(data10)
#print(data11)
#print(data12)
#print(data13)
#print(data14)
#print(data15)
#print(data16)
#print(data17)
#print(data18)
#print(data19)
#print(data20)
#print(data21)
#print(data22)
#print(data23)
#print(data24)
#print(data25)
#print(data26)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  int32
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
# Per data.info() earlier, 6 columns have nulls i.e "car", "Bar", "CoffeeHouse", "CarryAway", 
# "RestaurantLessThan20" and "Restaurant20To50"

# Enabling display of all columns to easily review the data for all columns
pd.options.display.max_columns = None

# Checking all column for records which have null
dataCoffeeHouseNull = data[data['CoffeeHouse'].isnull()]
dataCarNull = data[data['car'].isnull()]
dataBarNull = data[data['Bar'].isnull()]
dataCarryAwayNull = data[data['CarryAway'].isnull()]
dataRestaurantLessThan20Null = data[data['RestaurantLessThan20'].isnull()]
dataRestaurant20To50Null = data[data['Restaurant20To50'].isnull()]

# Printing (optional) but can be evaulated individually
#print(dataCoffeeHouseNull)
#print(dataCarNull)
#print(dataBarNull)
#print(dataCarryAwayNull)
#print(dataRestaurantLessThan20Null)
#print(dataRestaurant20To50Null)

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# Based on the evaluation, start cleaning the data. In this particular instance, Age has string values
# and replacing it's values with int and changing the type of the column will possibly help at a later point
# for charting and analyzing data

# Replace the two values in age from 50plus to 51 and below21 to 20 
# and convert the column to an int column
data["age"] = data["age"].str.replace("50plus", "51").str.replace("below21", "20")
data = data.astype({"age": int})

# %%
# For rest of the columns except "car", based on the analyses, since those records have null values,
# replacing it with "never" with the assumption that the user never visited those.
# Fill all the NaN with never since the user would not have gone to those
data["Bar"].fillna("never", inplace=True)
data["CoffeeHouse"].fillna("never", inplace=True)
data["CarryAway"].fillna("never", inplace=True)
data["RestaurantLessThan20"].fillna("never", inplace=True)
data["Restaurant20To50"].fillna("never", inplace=True)

# %%
# For further evaluation of data, Seaborn heatmap is used to understand the relationship of data
# between different numeric columns
sns.heatmap(data.corr(), cmap="YlGnBu", annot=True)

# In the plot below, one pattern is apparent in which the user closer to the restaurant, Bar 
# or CoffeeHouse is most likely to use the coupon vs. those who are far.
# Out:
# C:\Users\E-Radiance\AppData\Local\Temp\ipykernel_33356\1044775413.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap="YlGnBu", annot=True)
# <Axes: >

# %%
data.head(5)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender  age      maritalStatus  \
# 0        Restaurant(<20)         1d  Female   21  Unmarried partner
# 1           Coffee House         2h  Female   21  Unmarried partner
# 2  Carry out & Take away         2h  Female   21  Unmarried partner
# 3           Coffee House         2h  Female   21  Unmarried partner
# 4           Coffee House         1d  Female   21  Unmarried partner
#
#    has_children                 education  occupation           income  car  \
# 0             1  Some college - no degree  Unemployed  $37500 - $49999  NaN
# ...

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
# Calculating proportion of users accepting coupons
#data["totalproportionacceptedthecoupon"] = data[data["Y"]==1]/data.shape[0]
usersAcceptingCoupons = data[data["Y"]==1].shape[0]
print("Total Users accepting coupons:" , usersAcceptingCoupons)
totalUsers = data.shape[0]
print("Total Users:" ,totalUsers)
proportionUsingCoupons = (usersAcceptingCoupons/totalUsers) * 100
print("Proportion accepting coupons:" ,proportionUsingCoupons)
# Out:
# Total Users accepting coupons: 7210
# Total Users: 12684
# Proportion accepting coupons: 56.84326710816777

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
plt.figure(figsize = (4, 4))  #Size of plot
sns.barplot(data, x="coupon", y="Y", width=0.5)
plt.grid()  # Enable Grid
plt.title('Bar Plot of Coupon Usage') # Set Title of Plot
plt.xticks(rotation=45) # Rotate x axis label for better visibility
plt.ylabel("Accepted coupons (Y)") # Rename Y label for easy of understanding
# Out:
# Text(0, 0.5, 'Accepted coupons (Y)')

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.histplot(data, x="temperature", hue="coupon", kde=True)
# Based on the data, Users are going out more at higher temperatures than at lower temperatures
# Also, they tend to use more coupon in that scenario
# Out:
# <Axes: xlabel='temperature', ylabel='Count'>

# %%
sns.histplot(data, x="age", hue="coupon", kde=True)
# Based on age and coupon count, the # of people using coupon is more in 20s and 30s but decreases until 
# they pass the age of 45 when they start using more
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.jointplot(data=data, x="age", y="temperature",hue="coupon")
# Not a helpful plot but shows based on age group how many users go where based on temperature

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
# DataFrame with records for bar coupons
dataBarCoupons = data[data["coupon"] == "Bar"]
dataBarCoupons
print("Total DataBar Coupons:",dataBarCoupons.shape[0])
# Out:
# Total DataBar Coupons: 2017

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
# Total Bar coupon Records
totalBarCouponRecords = dataBarCoupons.shape[0]
# Bar Users who accepted the coupons
acceptedBarCouponRecords = dataBarCoupons[dataBarCoupons["Y"] == 1].shape[0]
# Proportion of Bar coupons accepted
proportionofBarCouponsAccepted = (acceptedBarCouponRecords/totalBarCouponRecords) * 100
print("Total Bar Coupons:", totalBarCouponRecords)
print("Accepted Bar Coupons:",acceptedBarCouponRecords)
print("Percentage of Accepted Bar Coupons:", proportionofBarCouponsAccepted)

#Total % of Bar coupons accepted is ~41%. This aligns with the Bar plot of Coupon Usage
# Out:
# Total Bar Coupons: 2017
# Accepted Bar Coupons: 827
# Percentage of Accepted Bar Coupons: 41.00148735746158

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
# Using the dataframe filter method
# DataFrame for users visiting bar 1 to 3 times
dataBar1To3 = dataBarCoupons[dataBarCoupons["Bar"] == "1~3"]
# DataFrame for users visiting bar less than 1 time
dataBarLess1 = dataBarCoupons[dataBarCoupons["Bar"] == "less1"]
# Acceptance of coupons of bar users visiting 1 to 3 times
acceptanceRate1To3 = dataBar1To3[dataBar1To3["Y"] == 1].shape[0]
# Acceptance of coupons of bar users visiting less than 1 time
acceptanceRateLess1 = dataBarLess1[dataBarLess1["Y"] == 1].shape[0]
# Adding total records for 1 to 3 times and less than 1 time
dataBar3OrFewer = dataBar1To3.shape[0] + dataBarLess1.shape[0]
print(dataBar3OrFewer)
# Acceptance Rate 3 or fewer times
acceptanceRate3orFewer = ((acceptanceRate1To3 + acceptanceRateLess1)/dataBar3OrFewer) * 100
print("Acceptance rate 1 To 3:", acceptanceRate1To3)
print("Acceptance rate less than 1:",acceptanceRateLess1)
print("Acceptance % fewer than 3 times:",acceptanceRate3orFewer)

# DataFrame of all Bar users visiting 4 to 8 times
dataBar4To8 = dataBarCoupons[dataBarCoupons["Bar"] == "4~8"]
# DataFrame of all Bar users visiting > 8 times
dataBarGreaterThan8 = dataBarCoupons[dataBarCoupons["Bar"] == "gt8"]
# total Acceptance of Bar users visiting 4 to 8 times
acceptanceRate4To8 = dataBar4To8[dataBar4To8["Y"] == 1].shape[0]
# total Acceptance of Bar users visiting > 8 times
acceptanceRateGreaterThan8 = dataBarGreaterThan8[dataBarGreaterThan8["Y"] == 1].shape[0]
# Total Users visiting more than 4 times
dataBar4OrMore = dataBar4To8.shape[0] + dataBarGreaterThan8.shape[0]
print(dataBar4OrMore)
# Total Acceptance for Bar Users visiting more than 4 times
acceptanceRate4OrMore = ((acceptanceRate4To8 + acceptanceRateGreaterThan8)/dataBar4OrMore) * 100
print("Acceptance rate 4 To 8:", acceptanceRate4To8)
print("Acceptance rate > 8 times:", acceptanceRateGreaterThan8)
print("Acceptance % > 4 times:", acceptanceRate4OrMore)
#dataBarCoupons["Bar"].value_counts()
# Out:
# 967
# Acceptance rate 1 To 3: 257
# Acceptance rate less than 1: 253
# Acceptance % fewer than 3 times: 52.74043433298863
# 199
# Acceptance rate 4 To 8: 117
# Acceptance rate > 8 times: 36
# Acceptance % > 4 times: 76.88442211055276

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# Bar users over 25 but under 30 (Excluding all ages except the over age of 25 including older ranges)
driversAgeOver25ButLessThan30 = dataBarCoupons.query('age == 26 and (Bar != "never" or Bar != "less1")')

# Acceptance of coupon by Users > 25 and < 30
acceptanceRatedriversAgeOver25ButLessThan30 = (driversAgeOver25ButLessThan30[driversAgeOver25ButLessThan30["Y"]==1].shape[0]/driversAgeOver25ButLessThan30.shape[0]) * 100
print("Acceptance Rate Users > 25 and < 30 and visit more than 1 times:", acceptanceRatedriversAgeOver25ButLessThan30)

# Bar user not > 25 and less than 30
driversAgeOtherThan25ButLessThan30 = dataBarCoupons.query('age != 26 and (Bar != "never" or Bar != "less1")')

# Acceptance of coupon by Users Not > 25 and < 30
acceptanceRatedriversAgeOtherThan25ButLessThan30 = (driversAgeOtherThan25ButLessThan30[driversAgeOtherThan25ButLessThan30["Y"] ==1].shape[0]/driversAgeOtherThan25ButLessThan30.shape[0]) * 100
print("Bar users > 25 and less than 30:", driversAgeOver25ButLessThan30.shape[0])
print("Bar users not (> 25 and less than 30):", driversAgeOtherThan25ButLessThan30.shape[0])
print("Total Bar Users:",dataBarCoupons.shape[0])
print("Acceptance Rate Users Not > 25 and < 30 and visit more than 1 times:", acceptanceRatedriversAgeOtherThan25ButLessThan30)
dataBarCoupons["age"].value_counts()
# Out:
# Acceptance Rate Users > 25 and < 30 and visit more than 1 times: 48.860759493670884
# Bar users > 25 and less than 30: 395
# Bar users not (> 25 and less than 30): 1622
# Total Bar Users: 2017
# Acceptance Rate Users Not > 25 and < 30 and visit more than 1 times: 39.08754623921085
# 21    417
# 26    395
# 31    339
# 51    283
# 36    209
# 41    178
# 46    109
# 20     87
# Name: age, dtype: int64

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
# Bar users who go more than once a month and are not accompanied by kids and 
# have occupation other than farming, fishing or forestry
driversWithCriteria = dataBarCoupons.query('Bar != "less1" and Bar != "never" and passanger != "Kid(s)" and (occupation != "farming" or occupation != "fishing" or occupation != "forestry")')
# Acceptance rate
acceptanceRatedriversWithCriteria = (driversWithCriteria.query('Y == 1').shape[0]/driversWithCriteria.shape[0]) * 100
print("Acceptance rate of coupons for this criteria:", acceptanceRatedriversWithCriteria)
# Out:
# Acceptance rate of coupons for this criteria: 70.298769771529

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
# Criteria1 - go to bars more than once a month, had passengers that were not a kid, and were not widowed 
driversWithCriteria1 = dataBarCoupons.query('Bar != "less1" and Bar != "never" and passanger != "Kid(s)" and maritalStatus != "Widowed" ')
acceptanceRateCriteria1 = (driversWithCriteria1.query('Y == 1').shape[0]/driversWithCriteria1.shape[0]) * 100
print("Acceptance rate Criteria1:", acceptanceRateCriteria1)
driversWithCriteria1

# Criteria2 - go to bars more than once a month and are under the age of 30
driversWithCriteria2 = dataBarCoupons.query('Bar != "less1" and Bar != "never" and (age == 26 or age == 21 or age == 20) ')
acceptanceRateCriteria2 = (driversWithCriteria2.query('Y == 1').shape[0]/driversWithCriteria2.shape[0]) * 100
print("Acceptance rate Criteria2:", acceptanceRateCriteria2)
driversWithCriteria2
# Criteria2 - go to cheap restaurants more than 4 times a month and income is less than 50K
driversWithCriteria3 = data.query('coupon == "Restaurant(<20)" and (RestaurantLessThan20 == "4~8" or RestaurantLessThan20 == "gt8") and (income == "Less than $12500" or income == "$12500 - $24999" or income == "$25000 - $37499" or income == "$37500 - $49999")')
acceptanceRateCriteria3 = (driversWithCriteria3.query('Y == 1').shape[0]/driversWithCriteria3.shape[0]) * 100
print("Acceptance rate Criteria3:", acceptanceRateCriteria3)
# Out:
# Acceptance rate Criteria1: 70.298769771529
# Acceptance rate Criteria2: 72.20630372492836
# Acceptance rate Criteria3: 71.08910891089108

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# ### My Observations:
# Based on the observation, all three group of users have an <b>acceptance rate of more than 70%</b>. Also, all users are under the age of 30 and don't have any kids.

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
#For this example, we are going to evaluate Restaurant(20-50) users based on the characteristics 
# of passengers who accept the coupons

dataRestaurant20To50 = data.query('coupon == "Restaurant(20-50)"')
dataRestaurant20To50["passanger"].value_counts()
# Out:
# Alone        1009
# Kid(s)        174
# Friend(s)     168
# Partner       141
# Name: passanger, dtype: int64

# %%
# Acceptance Rate of Users who are alone and accept the coupons 
dataRestaurant20To50Alone = dataRestaurant20To50.query('passanger == "Alone"')
acceptanceRateRestaurant20To50Alone = (dataRestaurant20To50Alone[dataRestaurant20To50Alone["Y"]==1].shape[0]/dataRestaurant20To50Alone.shape[0])* 100
print("Acceptance Rate of Users who are alone and accept the coupons:", acceptanceRateRestaurant20To50Alone)
# Out:
# Acceptance Rate of Users who are alone and accept the coupons 42.22001982160555

# %%
# Acceptance Rate of Users who are accompanied with Kids and accept the coupons 
dataRestaurant20To50WithKids = dataRestaurant20To50.query('passanger == "Kid(s)"')
acceptanceRateRestaurant20To50WithKids = (dataRestaurant20To50WithKids[dataRestaurant20To50WithKids["Y"]==1].shape[0]/dataRestaurant20To50WithKids.shape[0])* 100
print("Acceptance Rate of Users who are accompanied with Kids and accept the coupons:",acceptanceRateRestaurant20To50WithKids)
# Out:
# Acceptance Rate of Users who are accompanied with Kids and accept the coupons: 37.35632183908046

# %%
# Acceptance Rate of Users who are accompanied with Friends and accept the coupons 
dataRestaurant20To50WithFriends = dataRestaurant20To50.query('passanger == "Friend(s)"')
acceptanceRateRestaurant20To50WithFriends = (dataRestaurant20To50WithFriends[dataRestaurant20To50WithFriends["Y"]==1].shape[0]/dataRestaurant20To50WithFriends.shape[0])* 100
print("Acceptance Rate of Users who are accompanied with Friends and accept the coupons:", acceptanceRateRestaurant20To50WithFriends)
# Out:
# Acceptance Rate of Users who are accompanied with Friends and accept the coupons: 46.42857142857143

# %%
# Acceptance Rate of Users who are accompanied with Partner and accept the coupons 
dataRestaurant20To50WithPartner = dataRestaurant20To50.query('passanger == "Partner"')
acceptanceRateRestaurant20To50WithPartner = (dataRestaurant20To50WithPartner[dataRestaurant20To50WithPartner["Y"]==1].shape[0]/dataRestaurant20To50WithPartner.shape[0])* 100
print("Acceptance Rate of Users who are accompanied with Partner and accept the coupons:", acceptanceRateRestaurant20To50WithPartner)
# Out:
# Acceptance Rate of Users who are accompanied with Partner and accept the coupons: 63.12056737588653

# %% [markdown]
# Based on the analysis, Users accompanied with their partners are the ones who accept the coupons the most for expensive restaurants. They have an <b>acceptance rate of ~63%</b> while the % is hovering between <b>40-45%</b> for the rest of them.
#
# My next step would be to evaluate across some of the other categories and compare and figure out how many users accept the coupons and how many don't. Also, it would be good to compare the distance and acceptance of the coupon by the user
